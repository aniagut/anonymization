# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "./train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python38\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 10/10 [==============================] - 87s 3s/step - loss: 16.1914 - accuracy: 0.2036 - val_loss: 17.2396 - val_accuracy: 0.1953
#
# Epoch 00001: val_accuracy improved from -inf to 0.19531, saving model to best_model.h5
# Epoch 2/30
# 10/10 [==============================] - 31s 3s/step - loss: 16.5249 - accuracy: 0.2744 - val_loss: 11.0242 - val_accuracy: 0.3594
#
# Epoch 00002: val_accuracy improved from 0.19531 to 0.35938, saving model to best_model.h5
# Epoch 3/30
# 10/10 [==============================] - 30s 3s/step - loss: 10.2271 - accuracy: 0.3341 - val_loss: 10.0061 - val_accuracy: 0.3906
#
# Epoch 00003: val_accuracy improved from 0.35938 to 0.39062, saving model to best_model.h5
# Epoch 4/30
# 10/10 [==============================] - 31s 3s/step - loss: 9.9023 - accuracy: 0.3614 - val_loss: 6.6775 - val_accuracy: 0.3945
#
# Epoch 00004: val_accuracy improved from 0.39062 to 0.39453, saving model to best_model.h5
# Epoch 5/30
# 10/10 [==============================] - 36s 3s/step - loss: 6.5991 - accuracy: 0.4062 - val_loss: 5.5650 - val_accuracy: 0.4102
#
# Epoch 00005: val_accuracy improved from 0.39453 to 0.41016, saving model to best_model.h5
# Epoch 6/30
# 10/10 [==============================] - 34s 4s/step - loss: 5.7872 - accuracy: 0.4373 - val_loss: 4.8653 - val_accuracy: 0.4023
#
# Epoch 00006: val_accuracy did not improve from 0.41016
# Epoch 7/30
# 10/10 [==============================] - 38s 4s/step - loss: 5.5313 - accuracy: 0.3861 - val_loss: 5.7518 - val_accuracy: 0.4805
#
# Epoch 00007: val_accuracy improved from 0.41016 to 0.48047, saving model to best_model.h5
# Epoch 8/30
# 10/10 [==============================] - 34s 4s/step - loss: 6.2754 - accuracy: 0.4463 - val_loss: 8.3752 - val_accuracy: 0.3320
#
# Epoch 00008: val_accuracy did not improve from 0.48047
# Epoch 9/30
# 10/10 [==============================] - 42s 4s/step - loss: 8.5903 - accuracy: 0.3389 - val_loss: 8.3241 - val_accuracy: 0.4062
#
# Epoch 00009: val_accuracy did not improve from 0.48047
# Epoch 10/30
# 10/10 [==============================] - 38s 4s/step - loss: 6.4717 - accuracy: 0.4000 - val_loss: 6.3058 - val_accuracy: 0.4531
#
# Epoch 00010: val_accuracy did not improve from 0.48047
# Epoch 11/30
# 10/10 [==============================] - 42s 4s/step - loss: 7.2579 - accuracy: 0.3870 - val_loss: 6.3850 - val_accuracy: 0.4180
#
# Epoch 00011: val_accuracy did not improve from 0.48047
# Epoch 12/30
# 10/10 [==============================] - 41s 4s/step - loss: 6.2220 - accuracy: 0.4243 - val_loss: 5.5068 - val_accuracy: 0.4414
#
# Epoch 00012: val_accuracy did not improve from 0.48047
# Epoch 00012: early stopping

# %%
kaggle competitions download -c emotion-detection-from-facial-expressions
# Out:
#   File "<ipython-input-1-8c87a366fe58>", line 1
#     kaggle competitions download -c emotion-detection-from-facial-expressions
#            ^
# SyntaxError: invalid syntax

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("./best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "happy2.png"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\PIL\Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  the image is of sad
